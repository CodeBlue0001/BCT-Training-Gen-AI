# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeBlue0001/BCT-Training-Gen-AI/blob/main/BCT_GEN_AI_DAY_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("Enter your name")
city=input("Enter your city")
age=int(input("Enter your age"))
Lang=input("Enter the languages you know")


print(f"Name{name} \nage:{age} \ncity:{city}\nLanguages:{Lang}")
# Out:
# Enter your namedipayan
# Enter your citybaruipur
# Enter your age21
# Enter the languages you knowc python java javascript sql mongodb node js
# Namedipayan
#  age21
#  citybaruipur
# Languages:c python java javascript sql mongodb node js
